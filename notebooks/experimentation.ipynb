# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.data.load_data import load_dataset
from src.data.preprocess import full_preprocessing_pipeline

df = load_dataset()
df = full_preprocessing_pipeline(df)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import os
#       3 sys.path.append(os.path.abspath(".."))
# ----> 4 from src.data.load_data import load_dataset
#       5 from src.data.preprocess import full_preprocessing_pipeline
#       7 df = load_dataset()
#
# File d:\DEPI\depi_grad\src\data\load_data.py:3
#       1 import kagglehub
#       2 import os
# ----> 3 import pandas as pd
#       5 def load_dataset():
#       6     path = kagglehub.dataset_download("mewbius/ecommerce-products")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sherbeny\AppData\Local\Programs\Python\Python311\python.exe
