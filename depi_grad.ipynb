# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-432d4b1a-94b1-47bf-825e-5b225d664184" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-432d4b1a-94b1-47bf-825e-5b225d664184">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('productsfull2.csv')

# %%
df.head()
# Out:
#                                            colorname  \
# 0                                                 []
# 1  ['Bright Sapphire', 'Cactus', 'Night', 'Teal S...
# 2                              ['Mossy Oak Country']
# 3                                            ['Owl']
# 4                                ['Dark Gray Multi']
#
#                                                desc2  \
# 0                                                 []
# 1                                                 []
# 2  ["Maine State Game Wardens are the pinnacle of...
# 3                                                 []
# 4                                                 []
#
#                                          description fit  \
# 0  ["The world's #1-selling hunting knife in its ...  []
# 1  ["We've combined the freedom of a sandal with ...  []
# 2  ["This is the ultimate sportsman's day pack. D...  []
# 3  ['These fur-ocious kids’ animal slippers will ...  []
# ...

# %%
df.shape
# Out:
# (24714, 9)

# %%
df.columns
# Out:
# Index(['colorname', 'desc2', 'description', 'fit', 'fitinfo',
#        'fulldescription', 'itemid', 'name', 'url'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24714 entries, 0 to 24713
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   colorname        24714 non-null  object
#  1   desc2            24714 non-null  object
#  2   description      24714 non-null  object
#  3   fit              24714 non-null  object
#  4   fitinfo          24714 non-null  object
#  5   fulldescription  24714 non-null  object
#  6   itemid           24714 non-null  object
#  7   name             24714 non-null  object
#  8   url              24714 non-null  object
# dtypes: object(9)
# memory usage: 1.7+ MB

# %%
(df == "[]").sum()
# Out:
# colorname            616
# desc2              18207
# description          286
# fit                21319
# fitinfo            11382
# fulldescription        0
# itemid              7432
# name                   0
# url                    0
# dtype: int64

# %%
df = df[['name','fulldescription','colorname']]

# %%
df
# Out:
#                                           name  \
# 0              Buck 110 Folding Hunter's Knife
# 1                       Kids' Explorer Sandals
# 2                Maine Warden's Day Pack, Camo
# 3               Toddlers' Animal Paws Slippers
# 4      Toddlers' Baby Bogs Boots, Classic Dino
# ...                                        ...
# 24709                     Polar Fleece Blanket
# 24710           Border Floral Quilt Collection
# 24711                           Heated Blanket
# 24712          Maine-Made Cotton Twill Blanket
# 24713        Maine-Made Cotton Blanket, Stripe
#
#                                          fulldescription  \
# 0      ["The world's #1-selling hunting knife in its ...
# 1      ["We've combined the freedom of a sandal with ...
# 2      ["This is the ultimate sportsman's day pack. D...
# 3      ['These fur-ocious kids’ animal slippers will ...
# 4      ['Our Baby Bogs set the standard in toddlers’ ...
# ...

# %%
df.replace("[]",np.nan,inplace=True)

# %%
df=df.dropna(subset=['fulldescription'])

# %%
df['colorname'].fillna('unknown',inplace=True)
# Out:
# /tmp/ipykernel_161/3076638661.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['colorname'].fillna('unknown',inplace=True)

# %%
df.shape
# Out:
# (24714, 3)

# %%
df.isnull().sum()
# Out:
# name               0
# fulldescription    0
# colorname          0
# dtype: int64

# %%
df['fulldescription'].str.len().describe()
# Out:
# count    24714.000000
# mean      1047.272437
# std        743.538204
# min         37.000000
# 25%        617.000000
# 50%        817.000000
# 75%       1128.000000
# max       5035.000000
# Name: fulldescription, dtype: float64

# %% [markdown]
# replaced [] with NAN
#
# dropped some columns
#
# replaced NAN in colorname column with 'unknown'
#
# check that the description column is long enough for training
